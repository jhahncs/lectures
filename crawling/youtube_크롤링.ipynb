# %% [markdown]
# # 구글 API 설치 및 설정

# %%
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# 구글 클라우드 콘솔
#
# https://cloud.google.com/cloud-console?hl=ko
#
# 콘솔로 이동 --> API 및 서비스 --> API및 서비스 사용 설정 --> Youtube Data API v3 검색 --> 사용 버튼 클릭 --> 사용자 인증 정보 --> 사용자 인증 정보 만들기

# %%
from googleapiclient.discovery import build
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Google Cloud Console에서 발급받은 API 키
api_key = "AIzaSyAxDTxXuVQ4hZBBBOqnR_EbTjItOKSTMBc"

# YouTube Data API 사용
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # 유튜브 데이터 크롤링

# %% [markdown]
# YouTube Data API
#
# https://developers.google.com/youtube/v3/docs/search/list?hl=ko

# %%
import json
import csv

# 쇼츠 영상 검색
next_page_token = None
page_index = 0

f = open("output.csv", 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f, delimiter=',')
csv_writer.writerow(['Page','Title','URL'])
f.close()


while page_index < 2:  # 100개 이상의 영상을 가져오도록 설정

  page_index += 1
  search_response = youtube.search().list(
      part='snippet',
      maxResults=50,  # 가져올 영상 수 (최대 50개)
      q='아기상어 노래',  # 검색어
      type='video',
      videoDuration='short',  # 영상 길이를 쇼츠로 제한
      pageToken=next_page_token  # 다음 페이지 토큰 설정
  ).execute()
  print(search_response)
  # 검색 결과 출력


  f = open("output.csv", 'a', encoding='utf-8-sig', newline='')
  csv_writer = csv.writer(f, delimiter=',')

  for search_result in search_response.get('items', []):
      video_id = search_result['id']['videoId']
      video_title = search_result['snippet']['title']
      video_url = f'https://www.youtube.com/watch?v={video_id}'
            
      onerow = []
      onerow.append(page_index)
      onerow.append(video_title)
      onerow.append(video_url)
      csv_writer.writerow(onerow)
  f.close()

  # 다음 페이지 토큰 설정
  next_page_token = search_response.get('nextPageToken')

  if not next_page_token:
      break
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'ngXdRFBQg70Pz7ziAtlPD_0qeRk', 'nextPageToken': 'CDIQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 789379, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'drfk1Yd6tOTZbl9gD3kM0W2_xAw', 'id': {'kind': 'youtube#video', 'videoId': '761ae_KDg_Q'}, 'snippet': {'publishedAt': '2016-01-02T08:00:00Z', 'channelId': 'UCqXwKu6dKobXEQFhdKtiJLQ', 'title': '아기상어 | 상어가족 | 동물동요 | @BabyShark_Korean 핑크퐁! 인기동요', 'description': '더 좋은 영상을 위해 여러분의 의견을 들려주세요! 설문조사 참여하기 ✓ https://forms.gle/N2Rg7X18FHYNHYCL8 핑크퐁 아기상어 ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/761ae_KDg_Q/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/761ae_KDg_Q/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/761ae_KDg_Q/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '핑크퐁 (인기 동요・동화)', 'liveBroadcastContent': 'none', 'publishTime': '2016-01-02T08:00:0
# ...
